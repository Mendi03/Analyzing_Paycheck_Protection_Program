# %% [markdown]
# # **Business with Proceedings above $150000**

# %%
#data was read in the second code

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style
style.use('seaborn')
# %matplotlib inline

data1 = pd.read_csv('public_150k_plus_220403.csv')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968532 entries, 0 to 968531
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   968532 non-null  int64
#  1   DateApproved                 968532 non-null  object
#  2   SBAOfficeCode                968532 non-null  int64
#  3   ProcessingMethod             968532 non-null  object
#  4   BorrowerName                 968528 non-null  object
#  5   BorrowerAddress              968518 non-null  object
#  6   BorrowerCity                 968520 non-null  object
#  7   BorrowerState                968519 non-null  object
#  8   BorrowerZip                  968519 non-null  object
#  9   LoanStatusDate               835016 non-null  object
#  10  LoanStatus                   968532 non-null  object
#  11  Term                         968532 non-null  int64
# ...

# %%
#use this to check if files are different
# !md5sum public_150k_plus_220403.csv
# Out:
# 001ed9ce92dc2f4cf4761a45251e0840  public_150k_plus_220403.csv

# %%
test2 = data1.copy()

test2
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9547507704   05/01/2020            464              PPP
# 1       9777677704   05/01/2020            464              PPP
# 2       5791407702   05/01/2020           1013              PPP
# 3       6223567700   05/01/2020            920              PPP
# 4       9662437702   05/01/2020            101              PPP
# ...            ...          ...            ...              ...
# 968527  4395967002   04/03/2020            897              PPP
# 968528  6985647108   04/14/2020            897              PPP
# 968529  7996438405   02/12/2021            897              PPS
# 968530  9054647103   04/15/2020            897              PPP
# 968531  9184687004   04/09/2020            897              PPP
#
#                                              BorrowerName  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# ...

# %%
# Get a subset of rows, that satisfy a constraint

# Data for United States

public = test2['BorrowerName'] == 'TRANSACT TECHNOLOGIES INC'

test2[public]
# Out:
# Empty DataFrame
# Columns: [LoanNumber, DateApproved, SBAOfficeCode, ProcessingMethod, BorrowerName, BorrowerAddress, BorrowerCity, BorrowerState, BorrowerZip, LoanStatusDate, LoanStatus, Term, SBAGuarantyPercentage, InitialApprovalAmount, CurrentApprovalAmount, UndisbursedAmount, FranchiseName, ServicingLenderLocationID, ServicingLenderName, ServicingLenderAddress, ServicingLenderCity, ServicingLenderState, ServicingLenderZip, RuralUrbanIndicator, HubzoneIndicator, LMIIndicator, BusinessAgeDescription, ProjectCity, ProjectCountyName, ProjectState, ProjectZip, CD, JobsReported, NAICSCode, Race, Ethnicity, UTILITIES_PROCEED, PAYROLL_PROCEED, MORTGAGE_INTEREST_PROCEED, RENT_PROCEED, REFINANCE_EIDL_PROCEED, HEALTH_CARE_PROCEED, DEBT_INTEREST_PROCEED, BusinessType, OriginatingLenderLocationID, OriginatingLender, OriginatingLenderCity, OriginatingLenderState, Gender, Veteran, NonProfit, ForgivenessAmount, ForgivenessDate]
# Index: []
#
# [0 rows x 53 columns]

# %%
li20 = ['BusinessType', 'FranchiseName','LMIIndicator','CD']

subset03 = test2[li20]
subset03
# Out:
#                        BusinessType FranchiseName LMIIndicator     CD
# 0                       Corporation           NaN            N  SC-05
# 1               Sole Proprietorship           NaN            Y  SC-06
# 2           Non-Profit Organization           NaN            N  WA-07
# 3                       Corporation           NaN            N  CA-08
# 4                               NaN           NaN            N    NaN
# ...                             ...           ...          ...    ...
# 968527                  Corporation           NaN            N    WY-
# 968528  Non-Profit Childcare Center           NaN            N    WY-
# 968529     Subchapter S Corporation           NaN            N    WY-
# 968530                  Corporation           NaN            N    WY-
# 968531     Subchapter S Corporation           NaN            N    WY-
#
# [968532 rows x 4 columns]

# %%
test2.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        4
# BorrowerAddress                    14
# BorrowerCity                       12
# BorrowerState                      13
# BorrowerZip                        13
# LoanStatusDate                 133516
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  95
# FranchiseName                  933127
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# ...

# %%
li5 = ['UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED', 'DEBT_INTEREST_PROCEED']
sub5 = test2[li5]

sub6 = sub5.fillna(0.0)

sub6['TOTAL_PROCEEDS'] = sub6['UTILITIES_PROCEED'] + sub6['PAYROLL_PROCEED'] + sub6['MORTGAGE_INTEREST_PROCEED'] + sub6['RENT_PROCEED'] + sub6['REFINANCE_EIDL_PROCEED'] + sub6['HEALTH_CARE_PROCEED'] + sub6['DEBT_INTEREST_PROCEED']

li6 = ['TOTAL_PROCEEDS', 'UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED', 'DEBT_INTEREST_PROCEED']
sub7 = sub6[li6]

test2['TOTAL_PROCEEDS'] = sub7['TOTAL_PROCEEDS']

li7 = ['TOTAL_PROCEEDS', 'ForgivenessAmount','JobsReported','RuralUrbanIndicator']

#li7 = ['ForgivenessAmount']

fullSubset2 = test2[li7]

# %%
fullSubset2.isnull().sum()
# Out:
# TOTAL_PROCEEDS             0
# ForgivenessAmount      93710
# JobsReported               1
# RuralUrbanIndicator        0
# dtype: int64

# %%
fullSubset2.dropna(how='any', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
fullSubset2.isnull().sum()
# Out:
# TOTAL_PROCEEDS         0
# ForgivenessAmount      0
# JobsReported           0
# RuralUrbanIndicator    0
# dtype: int64

# %%
urbanSub2 = fullSubset2[fullSubset2['RuralUrbanIndicator'] == 'U']

urbanSub2
# Out:
#         TOTAL_PROCEEDS  ForgivenessAmount  JobsReported RuralUrbanIndicator
# 0            769358.78          773553.37          62.0                   U
# 1            736927.79          746336.24          73.0                   U
# 2            691355.00          696677.49          75.0                   U
# 3            499871.00          395264.11          21.0                   U
# 4            367437.00          370819.35          25.0                   U
# ...                ...                ...           ...                 ...
# 968522       150000.00          150700.00          16.0                   U
# 968524       149999.00          150575.34          36.0                   U
# 968527       150000.00          151037.50          15.0                   U
# 968528       150000.00          150789.04          42.0                   U
# 968529       149998.00          150743.84           5.0                   U
#
# [738629 rows x 4 columns]

# %%
ruralSub2 = fullSubset2[fullSubset2['RuralUrbanIndicator'] == 'R']

ruralSub2
# Out:
#         TOTAL_PROCEEDS  ForgivenessAmount  JobsReported RuralUrbanIndicator
# 14          7666768.00         7761324.81         295.0                   R
# 17          6528631.40         6598389.38         439.0                   R
# 21          5928882.00         5987841.44         267.0                   R
# 26          5019000.24         5075790.57         215.0                   R
# 29          4808473.42         4861564.24         145.0                   R
# ...                ...                ...           ...                 ...
# 968523       149999.00          151047.95          12.0                   R
# 968525       149999.00          151079.17           5.0                   R
# 968526       150000.00          150661.64          11.0                   R
# 968530       150000.00          152820.83           7.0                   R
# 968531       150000.00          152162.50          11.0                   R
#
# [136192 rows x 4 columns]

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 10), dpi=80)

#plt.xlim(0.0,10000000.0)

plt.xlabel("Loan Amount (US dollars)")
plt.ylabel("Number of Employees")

# %%
figure(figsize=(12, 10), dpi=80)

plt.xlabel("Forgiveness Amount (US dollars)")
plt.ylabel("Number of Employees")

plt.scatter(ruralSub2['ForgivenessAmount'],ruralSub2['JobsReported'], c="darkgreen");

# %%
figure(figsize=(12, 10), dpi=80)

plt.xlabel("Loan Amount (US dollars)")
plt.ylabel("Number of Employees")

plt.scatter(urbanSub2['TOTAL_PROCEEDS'],urbanSub2['JobsReported']);

# %%
figure(figsize=(12, 10), dpi=80)

plt.xlabel("Forgiveness Amount (US dollars)")
plt.ylabel("Number of Employees")

plt.scatter(urbanSub2['ForgivenessAmount'],urbanSub2['JobsReported']);

# %% [markdown]
# ## **Urban sub stuff**

# %%
X= urbanSub2['TOTAL_PROCEEDS']
y = urbanSub2['JobsReported']

from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression, ElasticNet, BayesianRidge, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, explained_variance_score, mean_squared_error, mean_absolute_error

r1 = LinearRegression()
r2 = RandomForestRegressor(n_estimators=10, random_state=1)
r3 = KNeighborsRegressor()
r4 = Ridge(alpha=1.0)
r5 = linear_model.BayesianRidge()
r6 = ElasticNet(random_state=0)

X = X.values.reshape(-1,1)

r1.fit(X, y)
r2.fit(X, y)
r3.fit(X, y)
r4.fit(X, y)
r5.fit(X, y)
r6.fit(X, y)

pred1 = r1.predict(X)
pred2 = r2.predict(X)
pred3 = r3.predict(X)
pred4 = r4.predict(X)
pred5 = r5.predict(X)
pred6 = r6.predict(X)

# now let's see the R^2 score for each model-
# Best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
# A constant model that always predicts the expected (average) value of y, disregarding the input features, would get an  score of 0.0.

print("LinearRegression r2 score: ", r2_score(y, pred1))
print("RandomForestRegressor r2 score: ", r2_score(y, pred2))
print("KNeighborsRegressor r2 score: ", r2_score(y, pred3))
print("Ridge r2 score: ", r2_score(y, pred4))
print("Bayesian Ridge r2 score: ", r2_score(y, pred5))
print("ElasticNet r2 score: ", r2_score(y, pred6))

print(".....")

# We can also check the explained variance of each model- The best possible score is 1.0, lower values are worse.
print("LinearRegression Explained Variance: ", explained_variance_score(y, pred1))
print("RandomForestRegressor Explained Variance: ", explained_variance_score(y, pred2))
print("KNeighborsRegressor Explained Variance: ", explained_variance_score(y, pred3))
print("Ridge Explained Variance: ", explained_variance_score(y, pred4))
print("Bayesian Ridge Explained Variance: ", explained_variance_score(y, pred5))
print("ElasticNet Explained Variance: ", explained_variance_score(y, pred6))
# Out:
# LinearRegression r2 score:  0.5630809469991149
# RandomForestRegressor r2 score:  0.7827286147409481
# KNeighborsRegressor r2 score:  0.6408304030143352
# Ridge r2 score:  0.5630809469991149
# Bayesian Ridge r2 score:  0.5630809469991147
# ElasticNet r2 score:  0.5630809469991145
# .....
# LinearRegression Explained Variance:  0.5630809469991149
# RandomForestRegressor Explained Variance:  0.7827286151769458
# KNeighborsRegressor Explained Variance:  0.6408754573786335
# Ridge Explained Variance:  0.5630809469991149
# Bayesian Ridge Explained Variance:  0.5630809469991147
# ElasticNet Explained Variance:  0.5630809469991145

# %%
X= urbanSub2['ForgivenessAmount']
y = urbanSub2['JobsReported']

r1 = LinearRegression()
r2 = RandomForestRegressor(n_estimators=10, random_state=1)
r3 = KNeighborsRegressor()
r4 = Ridge(alpha=1.0)
r5 = linear_model.BayesianRidge()
r6 = ElasticNet(random_state=0)

X = X.values.reshape(-1,1)

r1.fit(X, y)
r2.fit(X, y)
r3.fit(X, y)
r4.fit(X, y)
r5.fit(X, y)
r6.fit(X, y)

pred1 = r1.predict(X)
pred2 = r2.predict(X)
pred3 = r3.predict(X)
pred4 = r4.predict(X)
pred5 = r5.predict(X)
pred6 = r6.predict(X)

# now let's see the R^2 score for each model-
# Best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
# A constant model that always predicts the expected (average) value of y, disregarding the input features, would get an  score of 0.0.

print("LinearRegression r2 score: ", r2_score(y, pred1))
print("RandomForestRegressor r2 score: ", r2_score(y, pred2))
print("KNeighborsRegressor r2 score: ", r2_score(y, pred3))
print("Ridge r2 score: ", r2_score(y, pred4))
print("Bayesian Ridge r2 score: ", r2_score(y, pred5))
print("ElasticNet r2 score: ", r2_score(y, pred6))

print(".....")

# We can also check the explained variance of each model- The best possible score is 1.0, lower values are worse.
print("LinearRegression Explained Variance: ", explained_variance_score(y, pred1))
print("RandomForestRegressor Explained Variance: ", explained_variance_score(y, pred2))
print("KNeighborsRegressor Explained Variance: ", explained_variance_score(y, pred3))
print("Ridge Explained Variance: ", explained_variance_score(y, pred4))
print("Bayesian Ridge Explained Variance: ", explained_variance_score(y, pred5))
print("ElasticNet Explained Variance: ", explained_variance_score(y, pred6))
# Out:
# LinearRegression r2 score:  0.5584523131524168
# RandomForestRegressor r2 score:  0.8856711341622401
# KNeighborsRegressor r2 score:  0.6702080989274795
# Ridge r2 score:  0.5584523131524168
# Bayesian Ridge r2 score:  0.5584523131524168
# ElasticNet r2 score:  0.5584523131524168
# .....
# LinearRegression Explained Variance:  0.5584523131524168
# RandomForestRegressor Explained Variance:  0.885671313078474
# KNeighborsRegressor Explained Variance:  0.6702081080826447
# Ridge Explained Variance:  0.5584523131524168
# Bayesian Ridge Explained Variance:  0.5584523131524168
# ElasticNet Explained Variance:  0.5584523131524168

# %% [markdown]
# ## **Rural sub stuff**

# %%
X= ruralSub2['TOTAL_PROCEEDS']
y = ruralSub2['JobsReported']

r1 = LinearRegression()
r2 = RandomForestRegressor(n_estimators=10, random_state=1)
r3 = KNeighborsRegressor()
r4 = Ridge(alpha=1.0)
r5 = linear_model.BayesianRidge()
r6 = ElasticNet(random_state=0)

X = X.values.reshape(-1,1)

r1.fit(X, y)
r2.fit(X, y)
r3.fit(X, y)
r4.fit(X, y)
r5.fit(X, y)
r6.fit(X, y)

pred1 = r1.predict(X)
pred2 = r2.predict(X)
pred3 = r3.predict(X)
pred4 = r4.predict(X)
pred5 = r5.predict(X)
pred6 = r6.predict(X)

# now let's see the R^2 score for each model-
# Best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
# A constant model that always predicts the expected (average) value of y, disregarding the input features, would get an  score of 0.0.

print("LinearRegression r2 score: ", r2_score(y, pred1))
print("RandomForestRegressor r2 score: ", r2_score(y, pred2))
print("KNeighborsRegressor r2 score: ", r2_score(y, pred3))
print("Ridge r2 score: ", r2_score(y, pred4))
print("Bayesian Ridge r2 score: ", r2_score(y, pred5))
print("ElasticNet r2 score: ", r2_score(y, pred6))

print(".....")

# We can also check the explained variance of each model- The best possible score is 1.0, lower values are worse.
print("LinearRegression Explained Variance: ", explained_variance_score(y, pred1))
print("RandomForestRegressor Explained Variance: ", explained_variance_score(y, pred2))
print("KNeighborsRegressor Explained Variance: ", explained_variance_score(y, pred3))
print("Ridge Explained Variance: ", explained_variance_score(y, pred4))
print("Bayesian Ridge Explained Variance: ", explained_variance_score(y, pred5))
print("ElasticNet Explained Variance: ", explained_variance_score(y, pred6))
# Out:
# LinearRegression r2 score:  0.6242208814799899
# RandomForestRegressor r2 score:  0.8544358249777163
# KNeighborsRegressor r2 score:  0.7168108205948995
# Ridge r2 score:  0.6242208814799899
# Bayesian Ridge r2 score:  0.6242208814799899
# ElasticNet r2 score:  0.6242208814799897
# .....
# LinearRegression Explained Variance:  0.6242208814799899
# RandomForestRegressor Explained Variance:  0.8544358295496426
# KNeighborsRegressor Explained Variance:  0.7168108235335784
# Ridge Explained Variance:  0.6242208814799899
# Bayesian Ridge Explained Variance:  0.6242208814799899
# ElasticNet Explained Variance:  0.6242208814799897

# %%
X= ruralSub2['ForgivenessAmount']
y = ruralSub2['JobsReported']

r1 = LinearRegression()
r2 = RandomForestRegressor(n_estimators=10, random_state=1)
r3 = KNeighborsRegressor()
r4 = Ridge(alpha=1.0)
r5 = linear_model.BayesianRidge()
r6 = ElasticNet(random_state=0)

X = X.values.reshape(-1,1)

r1.fit(X, y)
r2.fit(X, y)
r3.fit(X, y)
r4.fit(X, y)
r5.fit(X, y)
r6.fit(X, y)

pred1 = r1.predict(X)
pred2 = r2.predict(X)
pred3 = r3.predict(X)
pred4 = r4.predict(X)
pred5 = r5.predict(X)
pred6 = r6.predict(X)

# now let's see the R^2 score for each model-
# Best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
# A constant model that always predicts the expected (average) value of y, disregarding the input features, would get an  score of 0.0.

print("LinearRegression r2 score: ", r2_score(y, pred1))
print("RandomForestRegressor r2 score: ", r2_score(y, pred2))
print("KNeighborsRegressor r2 score: ", r2_score(y, pred3))
print("Ridge r2 score: ", r2_score(y, pred4))
print("Bayesian Ridge r2 score: ", r2_score(y, pred5))
print("ElasticNet r2 score: ", r2_score(y, pred6))

print(".....")

# We can also check the explained variance of each model- The best possible score is 1.0, lower values are worse.
print("LinearRegression Explained Variance: ", explained_variance_score(y, pred1))
print("RandomForestRegressor Explained Variance: ", explained_variance_score(y, pred2))
print("KNeighborsRegressor Explained Variance: ", explained_variance_score(y, pred3))
print("Ridge Explained Variance: ", explained_variance_score(y, pred4))
print("Bayesian Ridge Explained Variance: ", explained_variance_score(y, pred5))
print("ElasticNet Explained Variance: ", explained_variance_score(y, pred6))
# Out:
# LinearRegression r2 score:  0.6239233318954645
# RandomForestRegressor r2 score:  0.9126921236043838
# KNeighborsRegressor r2 score:  0.7291018057770977
# Ridge r2 score:  0.6239233318954645
# Bayesian Ridge r2 score:  0.6239233318954642
# ElasticNet r2 score:  0.6239233318954642
# .....
# LinearRegression Explained Variance:  0.6239233318954645
# RandomForestRegressor Explained Variance:  0.9126924239413081
# KNeighborsRegressor Explained Variance:  0.729102039635426
# Ridge Explained Variance:  0.6239233318954645
# Bayesian Ridge Explained Variance:  0.6239233318954643
# ElasticNet Explained Variance:  0.6239233318954642
